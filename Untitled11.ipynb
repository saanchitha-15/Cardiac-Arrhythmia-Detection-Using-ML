#   inflating: data/train/Premature Ventricular Contractions/fig_233.png
#   inflating: data/train/Premature Ventricular Contractions/fig_234.png
#   inflating: data/train/Premature Ventricular Contractions/fig_235.png
#   inflating: data/train/Premature Ventricular Contractions/fig_236.png
#   inflating: data/train/Premature Ventricular Contractions/fig_237.png
#   inflating: data/train/Premature Ventricular Contractions/fig_238.png
#   inflating: data/train/Premature Ventricular Contractions/fig_239.png
#   inflating: data/train/Premature Ventricular Contractions/fig_24.png
#   inflating: data/train/Premature Ventricular Contractions/fig_240.png
#   inflating: data/train/Premature Ventricular Contractions/fig_241.png
#   inflating: data/train/Premature Ventricular Contractions/fig_242.png
#   inflating: data/train/Premature Ventricular Contractions/fig_243.png
#   inflating: data/train/Premature Ventricular Contractions/fig_244.png
#   inflating: data/train/Premature Ventricular Contractions/fig_245.png
#   inflating: data/train/Premature Ventricular Contractions/fig_246.png
#   inflating: data/train/Premature Ventricular Contractions/fig_247.png
#   inflating: data/train/Premature Ventricular Contractions/fig_248.png
#   inflating: data/train/Premature Ventricular Contractions/fig_249.png
#   inflating: data/train/Premature Ventricular Contractions/fig_25.png
#   inflating: data/train/Premature Ventricular Contractions/fig_250.png
#   inflating: data/train/Premature Ventricular Contractions/fig_251.png
#   inflating: data/train/Premature Ventricular Contractions/fig_252.png
#   inflating: data/train/Premature Ventricular Contractions/fig_253.png
#   inflating: data/train/Premature Ventricular Contractions/fig_254.png
#   inflating: data/train/Premature Ventricular Contractions/fig_255.png
#   inflating: data/train/Premature Ventricular Contractions/fig_256.png
#   inflating: data/train/Premature Ventricular Contractions/fig_257.png
#   inflating: data/train/Premature Ventricular Contractions/fig_258.png
#   inflating: data/train/Premature Ventricular Contractions/fig_259.png
#   inflating: data/train/Premature Ventricular Contractions/fig_26.png
#   inflating: data/train/Premature Ventricular Contractions/fig_260.png
#   inflating: data/train/Premature Ventricular Contractions/fig_261.png
#   inflating: data/train/Premature Ventricular Contractions/fig_262.png
#   inflating: data/train/Premature Ventricular Contractions/fig_263.png
#   inflating: data/train/Premature Ventricular Contractions/fig_264.png
#   inflating: data/train/Premature Ventricular Contractions/fig_265.png
#   inflating: data/train/Premature Ventricular Contractions/fig_266.png
#   inflating: data/train/Premature Ventricular Contractions/fig_267.png
#   inflating: data/train/Premature Ventricular Contractions/fig_268.png
#   inflating: data/train/Premature Ventricular Contractions/fig_269.png
#   inflating: data/train/Premature Ventricular Contractions/fig_27.png
#   inflating: data/train/Premature Ventricular Contractions/fig_270.png
#   inflating: data/train/Premature Ventricular Contractions/fig_271.png
#   inflating: data/train/Premature Ventricular Contractions/fig_272.png
#   inflating: data/train/Premature Ventricular Contractions/fig_273.png
#   inflating: data/train/Premature Ventricular Contractions/fig_274.png
# ...
#   inflating: data/train/Ventricular Fibrillation/VFEfig_30.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_300.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_301.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_302.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_303.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_304.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_305.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_306.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_307.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_308.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_309.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_31.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_310.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_311.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_312.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_313.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_314.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_315.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_316.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_317.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_318.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_319.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_32.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_320.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_321.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_322.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_323.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_324.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_325.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_326.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_327.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_328.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_329.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_33.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_330.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_331.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_332.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_333.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_334.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_335.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_336.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_337.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_338.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_339.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_34.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_340.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_341.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_342.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_343.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_344.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_345.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_346.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_347.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_348.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_349.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_35.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_350.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_351.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_352.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_353.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_354.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_355.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_356.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_357.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_358.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_359.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_36.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_360.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_361.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_362.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_363.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_364.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_365.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_366.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_367.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_368.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_369.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_37.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_370.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_371.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_372.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_373.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_374.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_375.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_376.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_377.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_378.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_379.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_38.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_380.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_381.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_382.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_383.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_384.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_385.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_386.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_387.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_388.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_389.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_39.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_390.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_391.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_392.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_393.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_394.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_395.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_396.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_397.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_398.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_399.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_40.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_400.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_401.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_402.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_403.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_404.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_405.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_406.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_407.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_408.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_409.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_41.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_410.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_411.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_412.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_413.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_414.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_415.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_416.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_417.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_418.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_419.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_42.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_420.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_421.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_422.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_423.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_424.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_425.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_426.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_427.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_428.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_429.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_43.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_430.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_431.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_432.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_433.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_434.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_435.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_436.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_437.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_438.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_439.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_44.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_440.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_441.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_442.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_443.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_444.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_445.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_446.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_447.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_448.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_449.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_45.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_450.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_451.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_452.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_453.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_454.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_455.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_456.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_457.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_458.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_459.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_46.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_460.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_461.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_462.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_463.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_464.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_465.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_466.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_467.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_468.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_469.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_47.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_470.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_471.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_472.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_48.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_49.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_50.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_51.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_52.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_53.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_54.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_55.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_56.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_57.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_58.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_59.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_60.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_61.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_62.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_63.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_64.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_65.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_66.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_67.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_68.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_69.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_70.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_71.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_72.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_73.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_74.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_75.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_76.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_77.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_78.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_79.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_80.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_81.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_82.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_83.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_84.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_85.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_86.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_87.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_88.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_89.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_90.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_91.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_92.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_93.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_94.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_95.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_96.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_97.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_98.png
#   inflating: data/train/Ventricular Fibrillation/VFEfig_99.png

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import logging

# %%
# %matplotlib inline

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
def create_cnn_dataset(directory, target_size, batch_size):
    """Create dataset for CNN without feature extraction"""
    datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        zoom_range=0.2,
        fill_mode='nearest'
    )

    generator = datagen.flow_from_directory(
        directory,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    return generator

# %%
def create_validation_dataset(directory, target_size, batch_size):
    """Create validation dataset without augmentation"""
    datagen = ImageDataGenerator(rescale=1./255)

    generator = datagen.flow_from_directory(
        directory,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False
    )

    return generator

# %%
train_dir = '/content/data/train'
test_dir = '/content/data/test'
target_size = (128, 128)  # Increased size for better feature extraction
batch_size = 32

# Create data generators
logger.info("Creating training dataset...")
train_generator = create_cnn_dataset(train_dir, target_size, batch_size)

logger.info("Creating validation dataset...")
test_generator = create_validation_dataset(test_dir, target_size, batch_size)

logger.info(f"Number of training samples: {train_generator.samples}")
logger.info(f"Number of test samples: {test_generator.samples}")
logger.info(f"Number of classes: {train_generator.num_classes}")
logger.info(f"Class indices: {train_generator.class_indices}")
# Out:
# Found 15341 images belonging to 6 classes.
# Found 6825 images belonging to 6 classes.

# %%
def build_custom_cnn(input_shape, num_classes):
    model = Sequential([
        # First Convolutional Block
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape, padding='same'),
        BatchNormalization(),
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        # Second Convolutional Block
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        # Third Convolutional Block
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        # Fourth Convolutional Block
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        # Fifth Convolutional Block
        Conv2D(512, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(512, (3, 3), activation='relu', padding='same'),
        GlobalAveragePooling2D(),  # Better than Flatten for reducing overfitting

        # Fully Connected Layers
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dropout(0.3),

        # Output layer
        Dense(num_classes, activation='softmax')
    ])

    return model

# %%
input_shape = (128, 128, 3)
num_classes = train_generator.num_classes

model = build_custom_cnn(input_shape, num_classes)
model.summary()

# Compile the model with optimized parameters
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', 'precision', 'recall']
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,146,918 (19.63 MB)
#  Trainable params: 5,143,398 (19.62 MB)
#  Non-trainable params: 3,520 (13.75 KB)

# %%
callbacks = [
    EarlyStopping(
        monitor='val_accuracy',
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-7,
        verbose=1
    )
]

# Calculate steps per epoch
steps_per_epoch = train_generator.samples // batch_size
validation_steps = test_generator.samples // batch_size

# Train the model
logger.info("Training model...")
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=test_generator,
    validation_steps=validation_steps,
    epochs=50,  # Increased epochs with early stopping
    callbacks=callbacks,
    verbose=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 117s 196ms/step - accuracy: 0.5669 - loss: 1.3535 - precision: 0.6482 - recall: 0.4845 - val_accuracy: 0.2413 - val_loss: 9.0220 - val_precision: 0.2413 - val_recall: 0.2413 - learning_rate: 0.0010
# Epoch 2/50
#   1/479 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.8125 - loss: 0.4494 - precision: 0.8621 - recall: 0.7812
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8125 - loss: 0.4494 - precision: 0.8621 - recall: 0.7812 - val_accuracy: 0.2413 - val_loss: 8.7850 - val_precision: 0.2413 - val_recall: 0.2413 - learning_rate: 0.0010
# Epoch 3/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 80s 167ms/step - accuracy: 0.7965 - loss: 0.6042 - precision: 0.8553 - recall: 0.7468 - val_accuracy: 0.2413 - val_loss: 24.4230 - val_precision: 0.2413 - val_recall: 0.2413 - learning_rate: 0.0010
# Epoch 4/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9688 - loss: 0.2661 - precision: 0.9655 - recall: 0.8750 - val_accuracy: 0.2413 - val_loss: 24.5537 - val_precision: 0.2413 - val_recall: 0.2413 - learning_rate: 0.0010
# Epoch 5/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 137s 168ms/step - accuracy: 0.8583 - loss: 0.4124 - precision: 0.8981 - recall: 0.8236 - val_accuracy: 0.4911 - val_loss: 1.7476 - val_precision: 0.5162 - val_recall: 0.4459 - learning_rate: 0.0010
# Epoch 6/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8125 - loss: 0.5536 - precision: 0.8667 - recall: 0.8125 - val_accuracy: 0.6036 - val_loss: 1.1470 - val_precision: 0.6574 - val_recall: 0.5528 - learning_rate: 0.0010
# Epoch 7/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 81s 170ms/step - accuracy: 0.8983 - loss: 0.3110 - precision: 0.9199 - recall: 0.8793 - val_accuracy: 0.2415 - val_loss: 9.0027 - val_precision: 0.2415 - val_recall: 0.2415 - learning_rate: 0.0010
# Epoch 8/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8750 - loss: 0.3101 - precision: 0.8750 - recall: 0.8750 - val_accuracy: 0.2428 - val_loss: 8.8402 - val_precision: 0.2428 - val_recall: 0.2428 - learning_rate: 0.0010
# Epoch 9/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 82s 171ms/step - accuracy: 0.9162 - loss: 0.2557 - precision: 0.9316 - recall: 0.9029 - val_accuracy: 0.6143 - val_loss: 1.2774 - val_precision: 0.6317 - val_recall: 0.5954 - learning_rate: 0.0010
# Epoch 10/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8750 - loss: 0.3800 - precision: 0.9655 - recall: 0.8750 - val_accuracy: 0.5515 - val_loss: 1.7280 - val_precision: 0.5627 - val_recall: 0.5364 - learning_rate: 0.0010
# Epoch 11/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9286 - loss: 0.2202 - precision: 0.9398 - recall: 0.9166
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 134s 167ms/step - accuracy: 0.9286 - loss: 0.2202 - precision: 0.9398 - recall: 0.9166 - val_accuracy: 0.2190 - val_loss: 6.3943 - val_precision: 0.2212 - val_recall: 0.2154 - learning_rate: 0.0010
# Epoch 12/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9375 - loss: 0.1457 - precision: 0.9375 - recall: 0.9375 - val_accuracy: 0.2192 - val_loss: 6.4120 - val_precision: 0.2212 - val_recall: 0.2154 - learning_rate: 2.0000e-04
# Epoch 13/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 142s 178ms/step - accuracy: 0.9485 - loss: 0.1570 - precision: 0.9573 - recall: 0.9400 - val_accuracy: 0.2343 - val_loss: 15.7642 - val_precision: 0.2343 - val_recall: 0.2343 - learning_rate: 2.0000e-04
# Epoch 14/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9688 - loss: 0.0456 - precision: 1.0000 - recall: 0.9688 - val_accuracy: 0.2277 - val_loss: 16.2712 - val_precision: 0.2277 - val_recall: 0.2277 - learning_rate: 2.0000e-04
# Epoch 15/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 130s 164ms/step - accuracy: 0.9572 - loss: 0.1374 - precision: 0.9640 - recall: 0.9504 - val_accuracy: 0.0333 - val_loss: 21.9438 - val_precision: 0.0333 - val_recall: 0.0333 - learning_rate: 2.0000e-04
# Epoch 16/50
#   1/479 ━━━━━━━━━━━━━━━━━━━━ 27s 58ms/step - accuracy: 0.9062 - loss: 0.1381 - precision: 0.9355 - recall: 0.9062
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9062 - loss: 0.1381 - precision: 0.9355 - recall: 0.9062 - val_accuracy: 0.0333 - val_loss: 22.6089 - val_precision: 0.0333 - val_recall: 0.0333 - learning_rate: 2.0000e-04
# Epoch 17/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 137s 166ms/step - accuracy: 0.9630 - loss: 0.1135 - precision: 0.9693 - recall: 0.9590 - val_accuracy: 0.3044 - val_loss: 8.0430 - val_precision: 0.3072 - val_recall: 0.2989 - learning_rate: 4.0000e-05
# Epoch 18/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9688 - loss: 0.0824 - precision: 0.9688 - recall: 0.9688 - val_accuracy: 0.2531 - val_loss: 9.1022 - val_precision: 0.2602 - val_recall: 0.2478 - learning_rate: 4.0000e-05
# Epoch 19/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 142s 175ms/step - accuracy: 0.9650 - loss: 0.1066 - precision: 0.9697 - recall: 0.9599 - val_accuracy: 0.9004 - val_loss: 0.4098 - val_precision: 0.9144 - val_recall: 0.8897 - learning_rate: 4.0000e-05
# Epoch 20/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9375 - loss: 0.1383 - precision: 0.9375 - recall: 0.9375 - val_accuracy: 0.9007 - val_loss: 0.4081 - val_precision: 0.9144 - val_recall: 0.8900 - learning_rate: 4.0000e-05
# Epoch 21/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 142s 187ms/step - accuracy: 0.9647 - loss: 0.1143 - precision: 0.9703 - recall: 0.9613 - val_accuracy: 0.1011 - val_loss: 12.3336 - val_precision: 0.1016 - val_recall: 0.1008 - learning_rate: 4.0000e-05
# Epoch 22/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9375 - loss: 0.2565 - precision: 0.9355 - recall: 0.9062 - val_accuracy: 0.1011 - val_loss: 12.3744 - val_precision: 0.1014 - val_recall: 0.1008 - learning_rate: 4.0000e-05
# Epoch 23/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 142s 196ms/step - accuracy: 0.9689 - loss: 0.0966 - precision: 0.9736 - recall: 0.9656 - val_accuracy: 0.9300 - val_loss: 0.2963 - val_precision: 0.9374 - val_recall: 0.9231 - learning_rate: 4.0000e-05
# Epoch 24/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9062 - loss: 0.1985 - precision: 0.9355 - recall: 0.9062 - val_accuracy: 0.9261 - val_loss: 0.2999 - val_precision: 0.9338 - val_recall: 0.9209 - learning_rate: 4.0000e-05
# Epoch 25/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 121s 164ms/step - accuracy: 0.9692 - loss: 0.0936 - precision: 0.9740 - recall: 0.9665 - val_accuracy: 0.9234 - val_loss: 0.3299 - val_precision: 0.9315 - val_recall: 0.9173 - learning_rate: 4.0000e-05
# Epoch 26/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 1.0000 - loss: 0.0157 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9234 - val_loss: 0.3305 - val_precision: 0.9314 - val_recall: 0.9165 - learning_rate: 4.0000e-05
# Epoch 27/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 79s 165ms/step - accuracy: 0.9699 - loss: 0.0888 - precision: 0.9749 - recall: 0.9671 - val_accuracy: 0.9168 - val_loss: 0.3771 - val_precision: 0.9259 - val_recall: 0.9096 - learning_rate: 4.0000e-05
# Epoch 28/50
#   1/479 ━━━━━━━━━━━━━━━━━━━━ 27s 58ms/step - accuracy: 0.8750 - loss: 0.2837 - precision: 0.9032 - recall: 0.8750
# Epoch 28: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8750 - loss: 0.2837 - precision: 0.9032 - recall: 0.8750 - val_accuracy: 0.9153 - val_loss: 0.3831 - val_precision: 0.9247 - val_recall: 0.9079 - learning_rate: 4.0000e-05
# Epoch 29/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 135s 162ms/step - accuracy: 0.9700 - loss: 0.0922 - precision: 0.9748 - recall: 0.9653 - val_accuracy: 0.9133 - val_loss: 0.3871 - val_precision: 0.9224 - val_recall: 0.9068 - learning_rate: 8.0000e-06
# Epoch 30/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 1.0000 - loss: 0.0285 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9134 - val_loss: 0.3871 - val_precision: 0.9224 - val_recall: 0.9065 - learning_rate: 8.0000e-06
# Epoch 31/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 141s 172ms/step - accuracy: 0.9702 - loss: 0.0946 - precision: 0.9752 - recall: 0.9670 - val_accuracy: 0.9140 - val_loss: 0.3905 - val_precision: 0.9218 - val_recall: 0.9085 - learning_rate: 8.0000e-06
# Epoch 32/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9062 - loss: 0.2265 - precision: 0.9062 - recall: 0.9062 - val_accuracy: 0.9139 - val_loss: 0.3915 - val_precision: 0.9219 - val_recall: 0.9086 - learning_rate: 8.0000e-06
# Epoch 33/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9698 - loss: 0.0895 - precision: 0.9739 - recall: 0.9672
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 79s 164ms/step - accuracy: 0.9698 - loss: 0.0895 - precision: 0.9739 - recall: 0.9672 - val_accuracy: 0.9178 - val_loss: 0.3671 - val_precision: 0.9258 - val_recall: 0.9123 - learning_rate: 8.0000e-06
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.

# %%
model.save('my_ECG_CNN.h5')
logger.info("Model saved as 'my_ECG_CNN.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def plot_training_history(history):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    # Plot accuracy
    axes[0, 0].plot(history.history['accuracy'], label='Training Accuracy')
    axes[0, 0].plot(history.history['val_accuracy'], label='Validation Accuracy')
    axes[0, 0].set_title('Model Accuracy')
    axes[0, 0].set_xlabel('Epoch')
    axes[0, 0].set_ylabel('Accuracy')
    axes[0, 0].legend()
    axes[0, 0].grid(True)

    # Plot loss
    axes[0, 1].plot(history.history['loss'], label='Training Loss')
    axes[0, 1].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 1].set_title('Model Loss')
    axes[0, 1].set_xlabel('Epoch')
    axes[0, 1].set_ylabel('Loss')
    axes[0, 1].legend()
    axes[0, 1].grid(True)

    # Plot precision
    axes[1, 0].plot(history.history['precision'], label='Training Precision')
    axes[1, 0].plot(history.history['val_precision'], label='Validation Precision')
    axes[1, 0].set_title('Model Precision')
    axes[1, 0].set_xlabel('Epoch')
    axes[1, 0].set_ylabel('Precision')
    axes[1, 0].legend()
    axes[1, 0].grid(True)

    # Plot recall
    axes[1, 1].plot(history.history['recall'], label='Training Recall')
    axes[1, 1].plot(history.history['val_recall'], label='Validation Recall')
    axes[1, 1].set_title('Model Recall')
    axes[1, 1].set_xlabel('Epoch')
    axes[1, 1].set_ylabel('Recall')
    axes[1, 1].legend()
    axes[1, 1].grid(True)

    plt.tight_layout()
    plt.show()

# Plot the training history
plot_training_history(history)

# %%
logger.info("Evaluating model...")
test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_generator, verbose=1)

print(f"\nFinal Test Results:")
print(f"Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9427 - loss: 0.2258 - precision: 0.9488 - recall: 0.9373
#
# Final Test Results:
# Test Accuracy: 0.9301 (93.01%)
# Test Precision: 0.9375
# Test Recall: 0.9232
# Test Loss: 0.2959

# %%
f1_score = 2 * (test_precision * test_recall) / (test_precision + test_recall)
print(f"F1 Score: {f1_score:.4f}")

if test_accuracy > 0.95:
    print(f"\n🎉 SUCCESS! Achieved {test_accuracy*100:.2f}% accuracy (>95% target met!)")
else:
    print(f"\n📈 Current accuracy: {test_accuracy*100:.2f}%. Consider:")
    print("- Increasing training data")
    print("- Fine-tuning hyperparameters")
    print("- Adding more data augmentation")
    print("- Training for more epochs")
# Out:
# F1 Score: 0.9303
#
# 📈 Current accuracy: 93.01%. Consider:
# - Increasing training data
# - Fine-tuning hyperparameters
# - Adding more data augmentation
# - Training for more epochs
